# %%
import openmc
import numpy as np
import neutronics_material_maker as nmm
import matplotlib.pyplot as plt
import openmc_source_plotter
from math import cos, pi

# %%
#materials
#air
air = openmc.Material(name='air')
air.add_element("O",0.210748,'ao')
air.add_element("N",0.784431,'ao')
air.add_element("Ar",0.004671,'ao')
air.add_element("C", 0.00015,'ao')
air.set_density("g/cm3", 0.001205)

#ground surface - concrete
#ground_material = nmm.Material.from_library("concrete_heavy").openmc_material
ground_material = openmc.Material(name='ground_material')
ground_material.add_element("H" , 0.0052, 'ao')
ground_material.add_element("O",  0.3273, 'ao')
ground_material.add_element("C", 0.004, 'ao')
ground_material.add_element("Si", 0.0224, 'ao')
ground_material.add_element("Ca",  0.0657, 'ao')
ground_material.add_element("Mg", 0.0021, 'ao')
ground_material.add_element("Al", 0.0038, 'ao')
ground_material.add_element("Fe", 0.568, 'ao')
ground_material.add_element("P", 0.0015, 'ao')
ground_material.set_density("g/cm3", 3.6)
mats = openmc.Materials([ground_material, air])
mats.export_to_xml()

# %%
#ground surface
air_surface = openmc.model.RectangularParallelepiped(-50000, 50000, -10000, 10000, 0, 100000)
air_cell = openmc.Cell(region=-air_surface, fill=air)

ground_surface = openmc.model.RectangularParallelepiped(-50000, 50000, -10000, 10000, -1000, 0)
ground_cell = openmc.Cell(region=-ground_surface, fill=ground_material)

xmin = openmc.XPlane(x0=-50001, boundary_type = 'vacuum')
xmax = openmc.XPlane(x0=50001, boundary_type = 'vacuum')
ymin = openmc.YPlane(y0=-10001, boundary_type = 'vacuum')
ymax = openmc.YPlane(y0=10001, boundary_type = 'vacuum')
zmin = openmc.ZPlane(z0=-1001, boundary_type = 'vacuum')
zmax = openmc.ZPlane(z0=100001, boundary_type = 'vacuum')

void_region = +xmin & -xmax & -ymax & +ymin & +zmin & -zmax

void_cell =  openmc.Cell(region=void_region)

universe = openmc.Universe(cells=[air_cell, void_cell, ground_cell])
geom = openmc.Geometry(universe)
geom.export_to_xml()

color_assignment = {void_cell: 'blue', ground_cell: 'red', air:'purple'}
plt.show(universe.plot(width=(300100, 301100), basis='xz', colors=color_assignment))
plt.show(universe.plot(width=(101100, 101100), basis='xy', colors=color_assignment))
plt.show(universe.plot(width=(21100, 21100), basis='yz', colors=color_assignment))

# %%
def sim_sett(theta):
    #create the source
    sett = openmc.Settings()
    sett.particles = 500000
    sett.batches = 4
    sett.inactive = 0
    sett.run_mode = 'fixed source'

    source = openmc.Source()
    source.particle = 'neutron'
    source.energy = openmc.stats.Discrete([19e6], [1])

    mu = openmc.stats.Uniform(cos(theta), 1.0)
    phi = openmc.stats.Uniform(0.0, 2*pi)
    source.angle  = openmc.stats.PolarAzimuthal(mu, phi, reference_uvw=(0, 0., 1))
    source.space = openmc.stats.Point((0,0,5000))
    sett.source = source
    
    #%matplotlib inline
    #plot = source.plot_source_direction()
    #plot.show()
    
    sett.export_to_xml()
    return sett

# %%
#mesh
air_mesh = openmc.RegularMesh(mesh_id=1, name="air_mesh")
air_mesh.dimension = [1000,1,1]
air_mesh.lower_left = [-50000,-10000, 0]

air_mesh.upper_right = [50000,10000, 100]
mesh_filter = openmc.MeshFilter(air_mesh)
# Out:
# /usr/local/lib/python3.9/dist-packages/openmc/mixin.py:70: IDWarning: Another MeshBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %%
#tally
def create_tally():
    tallies = openmc.Tallies()
    shine_tally = openmc.Tally(name='shine_tally')
    neutron_filter = openmc.ParticleFilter(['neutron'])
    shine_tally.scores  = ['flux']
    shine_tally.filters = [mesh_filter, neutron_filter]
    tallies.append(shine_tally)
    tallies.export_to_xml()
    return tallies

# %%
angles = np.array([5, 10, 20, 40,60,80, 90])
angles = np.deg2rad(angles)

# %%
df_list = []
for angle in angles:
    settings = sim_sett(angle)
    sim_tallies = create_tally()
    model = openmc.model.Model(geom, mats, settings, sim_tallies)
    # !rm *.h5
    results_filename = model.run()
    
    results = openmc.StatePoint(results_filename)
    flux_tally = results.get_tally(name="shine_tally")
    df = flux_tally.get_pandas_dataframe()
    df_list.append(df)
    results.close()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:02:38
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.3604e+00 seconds
#    Reading cross sections          = 7.2408e+00 seconds
#  Total time in simulation          = 2.8221e+01 seconds
#    Time in transport only          = 2.8136e+01 seconds
#    Time in active batches          = 2.8221e+01 seconds
#    Time accumulating tallies       = 7.7002e-02 seconds
#    Time writing statepoints        = 7.9503e-03 seconds
#  Total time for finalization       = 3.8300e-03 seconds
#  Total time elapsed                = 3.5605e+01 seconds
#  Calculation Rate (active)         = 70868.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.69908 +/- 0.00027
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:03:16
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.4658e+00 seconds
#    Reading cross sections          = 6.4248e+00 seconds
#  Total time in simulation          = 1.6259e+01 seconds
#    Time in transport only          = 1.6222e+01 seconds
#    Time in active batches          = 1.6259e+01 seconds
#    Time accumulating tallies       = 3.0036e-02 seconds
#    Time writing statepoints        = 6.7052e-03 seconds
#  Total time for finalization       = 5.9928e-03 seconds
#  Total time elapsed                = 2.2739e+01 seconds
#  Calculation Rate (active)         = 123011 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.70229 +/- 0.00031
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:03:41
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0257e+01 seconds
#    Reading cross sections          = 1.0138e+01 seconds
#  Total time in simulation          = 1.7580e+01 seconds
#    Time in transport only          = 1.7525e+01 seconds
#    Time in active batches          = 1.7580e+01 seconds
#    Time accumulating tallies       = 4.7965e-02 seconds
#    Time writing statepoints        = 6.2971e-03 seconds
#  Total time for finalization       = 4.6929e-03 seconds
#  Total time elapsed                = 2.7878e+01 seconds
#  Calculation Rate (active)         = 113768 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.71664 +/- 0.00031
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:04:10
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0300e+01 seconds
#    Reading cross sections          = 1.0142e+01 seconds
#  Total time in simulation          = 2.0844e+01 seconds
#    Time in transport only          = 2.0794e+01 seconds
#    Time in active batches          = 2.0844e+01 seconds
#    Time accumulating tallies       = 3.7935e-02 seconds
#    Time writing statepoints        = 8.2520e-03 seconds
#  Total time for finalization       = 3.8780e-03 seconds
#  Total time elapsed                = 3.1171e+01 seconds
#  Calculation Rate (active)         = 95950.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.75418 +/- 0.00028
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:04:43
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.1584e+00 seconds
#    Reading cross sections          = 7.0142e+00 seconds
#  Total time in simulation          = 1.9115e+01 seconds
#    Time in transport only          = 1.8996e+01 seconds
#    Time in active batches          = 1.9115e+01 seconds
#    Time accumulating tallies       = 8.2884e-02 seconds
#    Time writing statepoints        = 3.5243e-02 seconds
#  Total time for finalization       = 4.0985e-03 seconds
#  Total time elapsed                = 2.6289e+01 seconds
#  Calculation Rate (active)         = 104632 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.78437 +/- 0.00029
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:05:12
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0794e+01 seconds
#    Reading cross sections          = 1.0580e+01 seconds
#  Total time in simulation          = 1.4131e+01 seconds
#    Time in transport only          = 1.4037e+01 seconds
#    Time in active batches          = 1.4131e+01 seconds
#    Time accumulating tallies       = 8.6901e-02 seconds
#    Time writing statepoints        = 6.8292e-03 seconds
#  Total time for finalization       = 3.8331e-03 seconds
#  Total time elapsed                = 2.4947e+01 seconds
#  Calculation Rate (active)         = 141535 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.80530 +/- 0.00028
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-27 10:05:38
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.0183e+00 seconds
#    Reading cross sections          = 8.9439e+00 seconds
#  Total time in simulation          = 1.6455e+01 seconds
#    Time in transport only          = 1.6363e+01 seconds
#    Time in active batches          = 1.6455e+01 seconds
#    Time accumulating tallies       = 8.2246e-02 seconds
#    Time writing statepoints        = 8.0421e-03 seconds
#  Total time for finalization       = 2.4182e-02 seconds
#  Total time elapsed                = 2.5511e+01 seconds
#  Calculation Rate (active)         = 121541 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.81315 +/- 0.00026

# %%
mesh_vol = 0.1*20
distance_x = air_mesh.vertices[:,0,0,0]
for i, angle in enumerate(angles):
    df_list[i]["Angles"] = angle
air_mesh.vertices
# Out:
# array([[[[-50000., -10000.,      0.],
#          [-50000., -10000.,    100.]],
#
#         [[-50000.,  10000.,      0.],
#          [-50000.,  10000.,    100.]]],
#
#
#        [[[-49900., -10000.,      0.],
#          [-49900., -10000.,    100.]],
#
#         [[-49900.,  10000.,      0.],
#          [-49900.,  10000.,    100.]]],
#
#
#        [[[-49800., -10000.,      0.],
#          [-49800., -10000.,    100.]],
#
#         [[-49800.,  10000.,      0.],
#          [-49800.,  10000.,    100.]]],
#
#
#        ...,
#
#
#        [[[ 49800., -10000.,      0.],
#          [ 49800., -10000.,    100.]],
#
#         [[ 49800.,  10000.,      0.],
#          [ 49800.,  10000.,    100.]]],
#
#
#        [[[ 49900., -10000.,      0.],
#          [ 49900., -10000.,    100.]],
#
#         [[ 49900.,  10000.,      0.],
#          [ 49900.,  10000.,    100.]]],
#
#
#        [[[ 50000., -10000.,      0.],
#          [ 50000., -10000.,    100.]],
#
#         [[ 50000.,  10000.,      0.],
#          [ 50000.,  10000.,    100.]]]])

# %%
max_means = []
max_stds = []

for df in df_list[6:]:
    
    flux = df[df['score'] == 'flux']
    flux_mean = flux["mean"] / mesh_vol
    flux_std = flux["std. dev."] / mesh_vol
    max_means.append(np.max(flux_mean))
    max_stds.append(flux_std[np.argmax(flux_mean)])
    plt.errorbar(distance_x[:-1]/100, flux_mean, flux_std, label=(str(round(df["Angles"][0], 3))+ " rad"))
    #plt.plot(distance_x[:-1]/100, flux_mean, label=(str(round(df["Angles"][0], 3))+ " rad"))
    plt.legend()
    plt.xlabel("Distance in x-direction from Source (m)")
    plt.ylabel("Flux: Particle/Source Particle per $cm^2$")
    plt.axvline(x=0, ls='--', color='black')
    plt.xlim(-1,500)
    #plt.ylim(1,2)
    #plt.xscale('log')
    plt.yscale('log')

# %% [markdown]
# #plot flux as function of energy
# flux_array = np.array(flux_list)
# flux_array
# np.max(df_list[0]["mean"])

# %%
plt.loglog(angles, max_means, color='b', ls=None, marker='x')
plt.xlabel(r"Angle $\theta$ of distribution")
plt.ylabel("Flux p/sp per cm2")
plt.title("Flux as function of angular distribution")
# Out:
# Text(0.5, 1.0, 'Flux as function of angular distribution')
